# %% [markdown]
# <a href="https://colab.research.google.com/github/daredevil-sk/Digital-Financial-Literacy-Agent-SK/blob/main/notebooks/01_baseline_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#hi how are you

# %%
# !git clone https://github.com/3Techies/Bias-Detection-ML-models.git
# Out:
# fatal: destination path 'Bias-Detection-ML-models' already exists and is not an empty directory.

# %%
# %cd Bias-Detection-ML-models/notebooks
# Out:
# /content/Bias-Detection-ML-models/notebooks/Bias-Detection-ML-models/notebooks

# %%
import sys
import os

print("CWD:", os.getcwd())

sys.path.append(os.path.abspath(".."))

print("Files in root:", os.listdir(".."))

import config
print("SUCCESS: config imported")
# Out:
# CWD: /content/Bias-Detection-ML-models/notebooks/Bias-Detection-ML-models/notebooks
# Files in root: ['data', '.git', 'README.md', 'New Text Document.txt', 'LICENSE', 'notebooks', 'config.py', 'results', 'how-to-use-git.md', '.gitignore']
# SUCCESS: config imported

# %%
import pandas as pd
# %cd ..
print(config.DATA_PATH)
# Out:
# /content/Bias-Detection-ML-models/notebooks/Bias-Detection-ML-models
# data/loan_data.csv

# %%
df = pd.read_csv(config.DATA_PATH)
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...
